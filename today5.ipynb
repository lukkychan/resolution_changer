# %% [markdown]
# <a href="https://colab.research.google.com/github/lukkychan/resolution_changer/blob/main/today5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf frames
# !rm -rf frames/720p
# !rm -rf frames/360p
# !rm -rf scaled
# !rm -rf predicted
# !rm -rf Pre_orginal
# !rm -rf dataset
# !rm -rf dataset/720p
# !rm -rf dataset/360s
# !rm -rf checkpoints
# !rm -rf temp_model
# !rm -rf temp_scaled

# %%
# !mkdir -p frames/720p
# !mkdir -p frames/360p
# !mkdir scaled
# !mkdir predicted
# !mkdir dataset
# !mkdir -p dataset/720p
# !mkdir -p dataset/360p
# !mkdir checkpoints

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/checkpoints/model_epoch_9.pth /content/drive/MyDrive/model/model_epoch_9.pth
# !cp /content/checkpoint.txt /content/drive/MyDrive/model/checkpoint.txt

# %%
import cv2

# Specify the path to the video file
video_path = "/content/drive/MyDrive/model/360p.mp4"

# Specify the output folder to save the frames
output_folder = "/content/frames/360p/"

# Open the video file
video = cv2.VideoCapture(video_path)

# Get the total number of frames in the video
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
print(total_frames)

# Calculate the frame interval to evenly sample the frames
frame_interval = max(total_frames//total_frames, 1)

# Initialize a counter to keep track of the extracted frames
frame_count_1 = 0

# Loop through the frames and extract the desired number of frames
while True:
    # Read the current frame
    ret, frame = video.read()

    # Check if the frame was successfully read
    if not ret:
        break

    # Save the frame as an image file
    frame_path = f"{output_folder}{frame_count_1}.jpg"
    cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count_1 += 1

    # Move to the next frame based on the frame interval
    video.set(cv2.CAP_PROP_POS_FRAMES, frame_count_1 * frame_interval)

# Release the video capture object
video.release()
print(frame_count_1)
print("done.")
# Out:
# 2987
# 2987
# done.

# %%
import cv2

# Specify the path to the video file
video_path = "/content/drive/MyDrive/model/720p.mp4"

# Specify the output folder to save the frames
output_folder = "/content/frames/720p/"

# Open the video file
video = cv2.VideoCapture(video_path)

# Get the total number of frames in the video
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
print(total_frames)

# Calculate the frame interval to evenly sample the frames
frame_interval = max(total_frames // total_frames, 1)

# Initialize a counter to keep track of the extracted frames
frame_count_2 = 0

# Loop through the frames and extract the desired number of frames
while True:
    # Read the current frame
    ret, frame = video.read()

    # Check if the frame was successfully read
    if not ret:
        break

    # Save the frame as an image file
    frame_path = f"{output_folder}{frame_count_2}.jpg"
    cv2.imwrite(frame_path, frame)

    # Increment the frame count
    frame_count_2 += 1

    # Move to the next frame based on the frame interval
    video.set(cv2.CAP_PROP_POS_FRAMES, frame_count_2 * frame_interval)

# Release the video capture object
video.release()
print(frame_count_2)
print("done.")
# Out:
# 2986

# %%
import os
output_folder_1 = "/content/frames/360p/"
output_folder_2 = "/content/frames/720p/"
while True:
  if frame_count_1 == frame_count_2:
    break
  elif frame_count_1 > frame_count_2:
    os.remove(f"{output_folder_1}{frame_count_1-1}.jpg")
    frame_count_1-=1
  else:
    os.remove(f"{output_folder_2}{frame_count_2-1}.jpg")
    frame_count_2-=1
print(frame_count_1,frame_count_2)
# Out:
# 2986 2986

# %%
import os
import subprocess

def scale_images(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get a list of all image files in the input folder
    image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

    for image_file in image_files:
        # Construct the input and output file paths
        input_path = os.path.join(input_folder, image_file)
        output_path = os.path.join(output_folder, image_file)

        # Execute FFmpeg command to scale the image to 1920x1080
        command = ['ffmpeg', '-i', input_path, '-vf', 'scale=1280:720', output_path]
        subprocess.call(command)

# Specify the paths to the input folder and output folder
input_folder = '/content/frames/360p/'
output_folder = '/content/scaled/'

# Call the function to scale the images
scale_images(input_folder, output_folder)
print("scaling done.")
# Out:
# scaling done.

# %%
import cv2

# Specify the directory containing the original 1080p images
original_dir = '/content/scaled/'

# Create a directory to save the cropped images
#os.makedirs('path/to/save/cropped/images', exist_ok=True)
counter1 = 0
# Iterate over the images in the original directory
for filename in os.listdir(original_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust file extensions if needed
        # Load the original 1080p image
        original_path = os.path.join(original_dir, filename)
        original_image = cv2.imread(original_path)

        # Calculate the dimensions of each cropped part
        image_height, image_width, _ = original_image.shape
        crop_height = image_height // 2
        crop_width = image_width // 2

        # Crop the image into 9 equal parts and save them in ascending order

        for i in range(2):
            for j in range(2):
                start_x = j * crop_width
                start_y = i * crop_height
                end_x = start_x + crop_width
                end_y = start_y + crop_height

                cropped_image = original_image[start_y:end_y, start_x:end_x]

                # Save the cropped image
                save_path = os.path.join('/content/dataset/360p/', f'{counter1}.jpg')
                cv2.imwrite(save_path, cropped_image)

                counter1 += 1


# Print the size of the cropped image
cropped_height, cropped_width, _ = cropped_image.shape
print(f"Cropped Image {counter1} ({filename}) size: {cropped_width}x{cropped_height}")
print(counter1)
# Out:
# Cropped Image 11944 (1080.jpg) size: 640x360
# 11944

# %%
import os
import shutil

source_folder = "/content/dataset/360p/"
destination_folder_base = "/content/dataset/360p/"
num_images_per_folder = 125

image_count = 0
folder_count = 0

total_folders = counter1 // 125
print(total_folders)

for i in range(total_folders):
    # Create the destination folder path
    destination_folder = f"{destination_folder_base}{i + 1}"

    # Check if the destination folder already exists
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Move images to the destination folder
    for j in range(image_count + 1, image_count + 126):
        image = f"{j}.jpg"
        source_path = os.path.join(source_folder, image)
        destination_path = os.path.join(destination_folder, image)

        # Check if the source image file exists
        if os.path.exists(source_path):
            shutil.move(source_path, destination_path)

    # Update the counters
    image_count += num_images_per_folder

print("All images have been moved.")
remaining_images = [f for f in os.listdir(source_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]
print(len(remaining_images))
# Out:
# 95
# All images have been moved.
# 69

# %%
import cv2

# Specify the directory containing the original 1080p images
original_dir = '/content/frames/720p/'

# Create a directory to save the cropped images
#os.makedirs('path/to/save/cropped/images', exist_ok=True)
counter2 = 0
# Iterate over the images in the original directory
for filename in os.listdir(original_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust file extensions if needed
        # Load the original 1080p image
        original_path = os.path.join(original_dir, filename)
        original_image = cv2.imread(original_path)

        # Calculate the dimensions of each cropped part
        image_height, image_width, _ = original_image.shape
        crop_height = image_height // 2
        crop_width = image_width // 2

        # Crop the image into 9 equal parts and save them in ascending order

        for i in range(2):
            for j in range(2):
                start_x = j * crop_width
                start_y = i * crop_height
                end_x = start_x + crop_width
                end_y = start_y + crop_height

                cropped_image = original_image[start_y:end_y, start_x:end_x]

                # Save the cropped image
                save_path = os.path.join('/content/dataset/720p/', f'{counter2}.jpg')
                cv2.imwrite(save_path, cropped_image)

                counter2 += 1


# Print the size of the cropped image
cropped_height, cropped_width, _ = cropped_image.shape
print(f"Cropped Image {counter2} ({filename}) size: {cropped_width}x{cropped_height}")
print(counter2)
# Out:
# Cropped Image 11944 (1080.jpg) size: 640x360
# 11944

# %%
import os
import shutil

source_folder = "/content/dataset/720p/"
destination_folder_base = "/content/dataset/720p/"
num_images_per_folder = 125

image_count = 0
folder_count = 0

total_folders = counter1 // 125
print(total_folders)

for i in range(total_folders):
    # Create the destination folder path
    destination_folder = f"{destination_folder_base}{i + 1}"

    # Check if the destination folder already exists
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Move images to the destination folder
    for j in range(image_count + 1, image_count + 126):
        image = f"{j}.jpg"
        source_path = os.path.join(source_folder, image)
        destination_path = os.path.join(destination_folder, image)

        # Check if the source image file exists
        if os.path.exists(source_path):
            shutil.move(source_path, destination_path)

    # Update the counters
    image_count += num_images_per_folder

print("All images have been moved.")
remaining_images = [f for f in os.listdir(source_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]
print(len(remaining_images))
# Out:
# 95
# All images have been moved.
# 69

# %%
import torch
import gc
gc.collect()
# Clear GPU memory
torch.cuda.empty_cache()

# %%
import gc
import os
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor, ToPILImage
import matplotlib.pyplot as plt

# Step 1: Organize data and directories
original_dir = '/content/dataset/720p/1/'  # Directory containing original 1080p images
scaled_dir = '/content/dataset/360p/1/'  # Directory containing scaled images

# Step 2: Load and preprocess the images
original_images = []
scaled_images = []

for filename in os.listdir(original_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust file extensions if needed
        original_path = os.path.join(original_dir, filename)
        scaled_path = os.path.join(scaled_dir, filename)

        original_image = cv2.imread(original_path)
        scaled_image = cv2.imread(scaled_path)

        # Preprocess the images (resize and normalize)
        original_image = cv2.resize(original_image, (640, 360))
        scaled_image = cv2.resize(scaled_image, (640, 360))

        original_images.append(original_image)
        scaled_images.append(scaled_image)

original_images = np.array(original_images)
scaled_images = np.array(scaled_images)

original_images = original_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)
scaled_images = scaled_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Convert the input data to the correct shape and move to GPU
original_images = torch.from_numpy(original_images).to(device).float()
scaled_images = torch.from_numpy(scaled_images).to(device).float()

# Define the U-Net model architecture

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Encoder
        self.encoder1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder2 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder3 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

        # Decoder
        self.decoder5 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder6 = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder7 = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder8 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=1)
        )

    def forward(self, x):
        # Encoder
        x1 = self.encoder1(x)
        x2 = self.encoder2(x1)
        x3 = self.encoder3(x2)
        x4 = self.encoder4(x3)

        # Decoder
        d5 = self.decoder5(x4)
        d4 = self.decoder6(torch.cat([d5, x3], dim=1))
        d3 = self.decoder7(torch.cat([d4, x2], dim=1))
        d2 = self.decoder8(torch.cat([d3, x1], dim=1))

        return d2

# Step 2: Load the previous model checkpoint
#checkpoint_path = '/content/checkpoints/model_epoch_6.pth'  # Path to the previous model checkpoint file

# Create an instance of the U-Net model
model = UNet()

# Load the model checkpoint
# checkpoint = torch.load(checkpoint_path)
# model.load_state_dict(checkpoint['model_state_dict'])

# Move the model to GPU if available
model.to(device)

# Print the model architecture
#print(model)

# Step 5: Compile and train the model
criterion = nn.MSELoss()
learning_rate = 0.0001  # Set the learning rate
optimizer = optim.Adam(model.parameters(),lr=learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, verbose=True)
# Create lists to store training and validation losses
train_losses = []
val_losses = []

# Define a custom dataset
class CustomDataset(Dataset):
    def __init__(self, inputs, targets, transform=None):
        self.inputs = inputs
        self.targets = targets
        self.transform = transform

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_image = self.inputs[idx]
        target_image = self.targets[idx]

        # Convert tensors to PIL images
        input_image = ToPILImage()(input_image)
        target_image = ToPILImage()(target_image)

        if self.transform:
            input_image = self.transform(input_image)
            target_image = self.transform(target_image)

        return input_image, target_image


# Create dataloaders for training and validation
train_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())
train_dataloader = DataLoader(train_dataset, batch_size=10, shuffle=True)

val_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())  # Replace with your validation dataset
val_dataloader = DataLoader(val_dataset, batch_size=10, shuffle=False)

# Training loop
for epoch in range(9):
    running_loss = 0.0
    for inputs, targets in train_dataloader:
        inputs = inputs.to(device).float()  # Convert input data to float
        targets = targets.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch: {epoch+1}, Loss: {running_loss}")

    # Calculate training loss
    train_loss = running_loss / len(train_dataloader)
    train_losses.append(train_loss)

    # Calculate validation loss
    model.eval()
    with torch.no_grad():
        val_loss = 0.0
        for val_inputs, val_targets in val_dataloader:
            val_inputs = val_inputs.to(device).float()
            val_targets = val_targets.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_targets)

            val_loss += loss.item()

        val_loss /= len(val_dataloader)
        val_losses.append(val_loss)

    # Adjust learning rate based on the validation loss
    scheduler.step(val_loss)

    # Check for overfitting
    if epoch > 0:
        if val_losses[epoch] > val_losses[epoch-1]:
            print("Model is starting to overfit. Stopping training.")
            break

    # Save checkpoint after every epoch
    checkpoint_path = f'/content/checkpoints/model_epoch_{epoch+1}.pth'
    torch.save({
        'epoch': epoch+1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': running_loss
    }, checkpoint_path)
    print(f"Checkpoint saved at: {checkpoint_path}")
    with open("/content/checkpoint.txt",'w') as f:
      f.write(str(epoch+1))

# # Plot training and validation losses
# plt.plot(train_losses, label='Training Loss')
# plt.plot(val_losses, label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# Step 6: Save the trained model
torch.save(model.state_dict(), '/content/model.pth')
print("Model saved.")


# Perform memory cleanup
gc.collect()
# Clear GPU memory
torch.cuda.empty_cache()

# %% [markdown]
# RMS prop

# %%
import gc
import os
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor, ToPILImage
import matplotlib.pyplot as plt

# Step 1: Organize data and directories
original_dir = '/content/dataset/720p/1/'  # Directory containing original 1080p images
scaled_dir = '/content/dataset/360p/1/'  # Directory containing scaled images

# Step 2: Load and preprocess the images
original_images = []
scaled_images = []

for filename in os.listdir(original_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust file extensions if needed
        original_path = os.path.join(original_dir, filename)
        scaled_path = os.path.join(scaled_dir, filename)

        original_image = cv2.imread(original_path)
        scaled_image = cv2.imread(scaled_path)

        # Preprocess the images (resize and normalize)
        original_image = cv2.resize(original_image, (640, 360))
        scaled_image = cv2.resize(scaled_image, (640, 360))

        original_images.append(original_image)
        scaled_images.append(scaled_image)

original_images = np.array(original_images)
scaled_images = np.array(scaled_images)

original_images = original_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)
scaled_images = scaled_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Convert the input data to the correct shape and move to GPU
original_images = torch.from_numpy(original_images).to(device).float()
scaled_images = torch.from_numpy(scaled_images).to(device).float()

# Define the U-Net model architecture

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Encoder
        self.encoder1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder2 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder3 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

        # Decoder
        self.decoder5 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder6 = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder7 = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder8 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=1)
        )

    def forward(self, x):
        # Encoder
        x1 = self.encoder1(x)
        x2 = self.encoder2(x1)
        x3 = self.encoder3(x2)
        x4 = self.encoder4(x3)

        # Decoder
        d5 = self.decoder5(x4)
        d4 = self.decoder6(torch.cat([d5, x3], dim=1))
        d3 = self.decoder7(torch.cat([d4, x2], dim=1))
        d2 = self.decoder8(torch.cat([d3, x1], dim=1))

        return d2

# Step 2: Load the previous model checkpoint
#checkpoint_path = '/content/checkpoints/model_epoch_6.pth'  # Path to the previous model checkpoint file

# Create an instance of the U-Net model
model = UNet()

# Load the model checkpoint
# checkpoint = torch.load(checkpoint_path)
# model.load_state_dict(checkpoint['model_state_dict'])

# Move the model to GPU if available
model.to(device)

# Print the model architecture
#print(model)

# Step 5: Compile and train the model
criterion = nn.MSELoss()
learning_rate = 0.0001  # Set the learning rate
optimizer = optim.RMSprop(model.parameters(), lr=learning_rate) # Use the SGD optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, verbose=True)
# Create lists to store training and validation losses
train_losses = []
val_losses = []

# Define a custom dataset
class CustomDataset(Dataset):
    def __init__(self, inputs, targets, transform=None):
        self.inputs = inputs
        self.targets = targets
        self.transform = transform

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_image = self.inputs[idx]
        target_image = self.targets[idx]

        # Convert tensors to PIL images
        input_image = ToPILImage()(input_image)
        target_image = ToPILImage()(target_image)

        if self.transform:
            input_image = self.transform(input_image)
            target_image = self.transform(target_image)

        return input_image, target_image


# Create dataloaders for training and validation
train_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())
train_dataloader = DataLoader(train_dataset, batch_size=10, shuffle=True)

val_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())  # Replace with your validation dataset
val_dataloader = DataLoader(val_dataset, batch_size=10, shuffle=False)

# Training loop
for epoch in range(9):
    running_loss = 0.0
    for inputs, targets in train_dataloader:
        inputs = inputs.to(device).float()  # Convert input data to float
        targets = targets.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch: {epoch+1}, Loss: {running_loss}")

    # Calculate training loss
    train_loss = running_loss / len(train_dataloader)
    train_losses.append(train_loss)

    # Calculate validation loss
    model.eval()
    with torch.no_grad():
        val_loss = 0.0
        for val_inputs, val_targets in val_dataloader:
            val_inputs = val_inputs.to(device).float()
            val_targets = val_targets.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_targets)

            val_loss += loss.item()

        val_loss /= len(val_dataloader)
        val_losses.append(val_loss)

    # Adjust learning rate based on the validation loss
    scheduler.step(val_loss)

    # Check for overfitting
    if epoch > 0:
        if val_losses[epoch] > val_losses[epoch-1]:
            print("Model is starting to overfit. Stopping training.")
            break

    # Save checkpoint after every epoch
    checkpoint_path = f'/content/checkpoints/model_epoch_{epoch+1}.pth'
    torch.save({
        'epoch': epoch+1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': running_loss
    }, checkpoint_path)
    print(f"Checkpoint saved at: {checkpoint_path}")
    with open("/content/checkpoint.txt",'w') as f:
      f.write(str(epoch+1))

# # Plot training and validation losses
# plt.plot(train_losses, label='Training Loss')
# plt.plot(val_losses, label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# Step 6: Save the trained model
torch.save(model.state_dict(), '/content/model2.pth')
print("Model saved.")


# Perform memory cleanup
gc.collect()
# Clear GPU memory
torch.cuda.empty_cache()
# Out:
# Epoch: 1, Loss: 6.450199842453003
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 1.3736733794212341
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.7081703934818506
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.5880046784877777
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.5333125833421946
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.4930247887969017
# Model is starting to overfit. Stopping training.
# Model saved.

# %% [markdown]
# TPU

# %%
import gc
import os
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor, ToPILImage
import matplotlib.pyplot as plt

# Step 1: Organize data and directories
original_dir = '/content/dataset/720p/1/'  # Directory containing original 1080p images
scaled_dir = '/content/dataset/360p/1/'  # Directory containing scaled images

# Step 2: Load and preprocess the images
original_images = []
scaled_images = []

for filename in os.listdir(original_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust file extensions if needed
        original_path = os.path.join(original_dir, filename)
        scaled_path = os.path.join(scaled_dir, filename)

        original_image = cv2.imread(original_path)
        scaled_image = cv2.imread(scaled_path)

        # Preprocess the images (resize and normalize)
        original_image = cv2.resize(original_image, (640, 360))
        scaled_image = cv2.resize(scaled_image, (640, 360))

        original_images.append(original_image)
        scaled_images.append(scaled_image)

original_images = np.array(original_images)
scaled_images = np.array(scaled_images)

original_images = original_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)
scaled_images = scaled_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Convert the input data to the correct shape and move to GPU
original_images = torch.from_numpy(original_images).to(device).float()
scaled_images = torch.from_numpy(scaled_images).to(device).float()

# Initialize the TPU device
import torch_xla.core.xla_model as xm
device = xm.xla_device()

# Define the U-Net model architecture

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Encoder
        self.encoder1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder2 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder3 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

        # Decoder
        self.decoder5 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder6 = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder7 = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder8 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=1)
        )

    def forward(self, x):
        # Encoder
        x1 = self.encoder1(x)
        x2 = self.encoder2(x1)
        x3 = self.encoder3(x2)
        x4 = self.encoder4(x3)

        # Decoder
        d5 = self.decoder5(x4)
        d4 = self.decoder6(torch.cat([d5, x3], dim=1))
        d3 = self.decoder7(torch.cat([d4, x2], dim=1))
        d2 = self.decoder8(torch.cat([d3, x1], dim=1))

        return d2

# Step 2: Load the previous model checkpoint
#checkpoint_path = '/content/checkpoints/model_epoch_6.pth'  # Path to the previous model checkpoint file

# Create an instance of the U-Net model
model = UNet()

# Load the model checkpoint
# checkpoint = torch.load(checkpoint_path)
# model.load_state_dict(checkpoint['model_state_dict'])

# Move the model to GPU if available
model.to(device)

# Print the model architecture
#print(model)

# Step 5: Compile and train the model
criterion = nn.MSELoss()
learning_rate = 0.0001  # Set the learning rate
optimizer = optim.Adam(model.parameters(),lr=learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, verbose=True)
# Create lists to store training and validation losses
train_losses = []
val_losses = []

# Define a custom dataset
class CustomDataset(Dataset):
    def __init__(self, inputs, targets, transform=None):
        self.inputs = inputs
        self.targets = targets
        self.transform = transform

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_image = self.inputs[idx]
        target_image = self.targets[idx]

        # Convert tensors to PIL images
        input_image = ToPILImage()(input_image)
        target_image = ToPILImage()(target_image)

        if self.transform:
            input_image = self.transform(input_image)
            target_image = self.transform(target_image)

        return input_image, target_image


# Create dataloaders for training and validation
train_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())
train_dataloader = DataLoader(train_dataset, batch_size=10, shuffle=True)

val_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())  # Replace with your validation dataset
val_dataloader = DataLoader(val_dataset, batch_size=10, shuffle=False)

# Training loop
for epoch in range(9):
    running_loss = 0.0
    for inputs, targets in train_dataloader:
        inputs = inputs.to(device).float()  # Convert input data to float
        targets = targets.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch: {epoch+1}, Loss: {running_loss}")

    # Calculate training loss
    train_loss = running_loss / len(train_dataloader)
    train_losses.append(train_loss)

    # Calculate validation loss
    model.eval()
    with torch.no_grad():
        val_loss = 0.0
        for val_inputs, val_targets in val_dataloader:
            val_inputs = val_inputs.to(device).float()
            val_targets = val_targets.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_targets)

            val_loss += loss.item()

        val_loss /= len(val_dataloader)
        val_losses.append(val_loss)

    # Adjust learning rate based on the validation loss
    scheduler.step(val_loss)

    # Check for overfitting
    if epoch > 0:
        if val_losses[epoch] > val_losses[epoch-1]:
            print("Model is starting to overfit. Stopping training.")
            break

    # Save checkpoint after every epoch
    checkpoint_path = f'/content/checkpoints/model_epoch_{epoch+1}.pth'
    torch.save({
        'epoch': epoch+1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': running_loss
    }, checkpoint_path)
    print(f"Checkpoint saved at: {checkpoint_path}")
    with open("/content/checkpoint.txt",'w') as f:
      f.write(str(epoch+1))

# # Plot training and validation losses
# plt.plot(train_losses, label='Training Loss')
# plt.plot(val_losses, label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# Step 6: Save the trained model
torch.save(model.state_dict(), '/content/model.pth')
print("Model saved.")


# Perform memory cleanup
gc.collect()
# Clear GPU memory
torch.cuda.empty_cache()
# Out:
# Collecting torch_xla
#   Downloading torch_xla-1.0-py3-none-any.whl (1.4 kB)
# Installing collected packages: torch_xla
# Successfully installed torch_xla-1.0

# %%
#checkpoint=9
#total_folders=95

# %%
import gc
import os
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor, ToPILImage
import matplotlib.pyplot as plt

def train(m):
  # Step 1: Organize data and directories
  original_dir = f'/content/dataset/720p/{m}/'  # Directory containing original 1080p images
  scaled_dir = f'/content/dataset/360p/{m}/'  # Directory containing scaled images

  # Step 2: Load and preprocess the images
  original_images = []
  scaled_images = []

  for filename in os.listdir(original_dir):
      if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust file extensions if needed
          original_path = os.path.join(original_dir, filename)
          scaled_path = os.path.join(scaled_dir, filename)

          original_image = cv2.imread(original_path)
          scaled_image = cv2.imread(scaled_path)

          # Preprocess the images (resize and normalize)
          original_image = cv2.resize(original_image, (640, 360))
          scaled_image = cv2.resize(scaled_image, (640, 360))

          original_images.append(original_image)
          scaled_images.append(scaled_image)

  original_images = np.array(original_images)
  scaled_images = np.array(scaled_images)

  original_images = original_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)
  scaled_images = scaled_images.transpose((0, 3, 1, 2))  # Transpose from (num_samples, 640, 360, 3) to (num_samples, 3, 640, 360)

  # Move the model to GPU if available
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

  # Convert the input data to the correct shape and move to GPU
  original_images = torch.from_numpy(original_images).to(device).float()
  scaled_images = torch.from_numpy(scaled_images).to(device).float()

  # Define the U-Net model architecture

  class UNet(nn.Module):
      def __init__(self):
          super(UNet, self).__init__()

          # Encoder
          self.encoder1 = nn.Sequential(
              nn.Conv2d(3, 64, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(64, 64, kernel_size=3, padding=1),
              nn.ReLU(inplace=True)
          )
          self.encoder2 = nn.Sequential(
              nn.MaxPool2d(kernel_size=2, stride=2),
              nn.Conv2d(64, 128, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(128, 128, kernel_size=3, padding=1),
              nn.ReLU(inplace=True)
          )
          self.encoder3 = nn.Sequential(
              nn.MaxPool2d(kernel_size=2, stride=2),
              nn.Conv2d(128, 256, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(256, 256, kernel_size=3, padding=1),
              nn.ReLU(inplace=True)
          )
          self.encoder4 = nn.Sequential(
              nn.MaxPool2d(kernel_size=2, stride=2),
              nn.Conv2d(256, 512, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(512, 512, kernel_size=3, padding=1),
              nn.ReLU(inplace=True)
          )

          # Decoder
          self.decoder5 = nn.Sequential(
              nn.Conv2d(512, 512, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(512, 256, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
          )
          self.decoder6 = nn.Sequential(
              nn.Conv2d(512, 256, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(256, 128, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
          )
          self.decoder7 = nn.Sequential(
              nn.Conv2d(256, 128, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(128, 64, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
          )
          self.decoder8 = nn.Sequential(
              nn.Conv2d(128, 64, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(64, 64, kernel_size=3, padding=1),
              nn.ReLU(inplace=True),
              nn.Conv2d(64, 3, kernel_size=1)
          )

      def forward(self, x):
          # Encoder
          x1 = self.encoder1(x)
          x2 = self.encoder2(x1)
          x3 = self.encoder3(x2)
          x4 = self.encoder4(x3)

          # Decoder
          d5 = self.decoder5(x4)
          d4 = self.decoder6(torch.cat([d5, x3], dim=1))
          d3 = self.decoder7(torch.cat([d4, x2], dim=1))
          d2 = self.decoder8(torch.cat([d3, x1], dim=1))

          return d2

  # Step 2: Load the previous model checkpoint
  with open("/content/checkpoint.txt",'r') as f:
      k=f.readline()
  print(k)
  checkpoint_path = f'/content/checkpoints/model_epoch_{int(k)}.pth'  # Path to the previous model checkpoint file

  # Create an instance of the U-Net model
  model = UNet()

  # Load the model checkpoint
  checkpoint = torch.load(checkpoint_path)
  model.load_state_dict(checkpoint['model_state_dict'])

  # Move the model to GPU if available
  model.to(device)

  # Print the model architecture
  #print(model)

  # Step 5: Compile and train the model
  criterion = nn.MSELoss()
  optimizer = optim.Adam(model.parameters())
  scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=2, verbose=True)
  # Create lists to store training and validation losses
  train_losses = []
  val_losses = []

  # Define a custom dataset
  class CustomDataset(Dataset):
      def __init__(self, inputs, targets, transform=None):
          self.inputs = inputs
          self.targets = targets
          self.transform = transform

      def __len__(self):
          return len(self.inputs)

      def __getitem__(self, idx):
          input_image = self.inputs[idx]
          target_image = self.targets[idx]

          # Convert tensors to PIL images
          input_image = ToPILImage()(input_image)
          target_image = ToPILImage()(target_image)

          if self.transform:
              input_image = self.transform(input_image)
              target_image = self.transform(target_image)

          return input_image, target_image


  # Create dataloaders for training and validation
  train_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())
  train_dataloader = DataLoader(train_dataset, batch_size=10, shuffle=True)

  val_dataset = CustomDataset(scaled_images, original_images, transform=ToTensor())  # Replace with your validation dataset
  val_dataloader = DataLoader(val_dataset, batch_size=10, shuffle=False)

  # Training loop
  for epoch in range(9):
      running_loss = 0.0
      for inputs, targets in train_dataloader:
          inputs = inputs.to(device).float()  # Convert input data to float
          targets = targets.to(device)

          optimizer.zero_grad()

          outputs = model(inputs)
          loss = criterion(outputs, targets)

          loss.backward()
          optimizer.step()

          running_loss += loss.item()

      print(f"Epoch: {epoch+1}, Loss: {running_loss}")

      # Calculate training loss
      train_loss = running_loss / len(train_dataloader)
      train_losses.append(train_loss)

      # Calculate validation loss
      model.eval()
      with torch.no_grad():
          val_loss = 0.0
          for val_inputs, val_targets in val_dataloader:
              val_inputs = val_inputs.to(device).float()
              val_targets = val_targets.to(device)

              val_outputs = model(val_inputs)
              loss = criterion(val_outputs, val_targets)

              val_loss += loss.item()

          val_loss /= len(val_dataloader)
          val_losses.append(val_loss)

      # Adjust learning rate based on the validation loss
      scheduler.step(val_loss)

      # Check for overfitting
      if epoch > 0:
          if val_losses[epoch] > val_losses[epoch-1]:
              print("Model is starting to overfit. Stopping training.")
              break

      # Save checkpoint after every epoch
      checkpoint_path = f'/content/checkpoints/model_epoch_{epoch+1}.pth'
      torch.save({
          'epoch': epoch+1,
          'model_state_dict': model.state_dict(),
          'optimizer_state_dict': optimizer.state_dict(),
          'loss': running_loss
      }, checkpoint_path)
      print(f"Checkpoint saved at: {checkpoint_path}")
      with open("/content/checkpoint.txt",'w') as f:
        f.write(str(epoch+1))
  # Step 6: Save the trained model
  torch.save(model.state_dict(), '/content/model.pth')
  print("Model saved.")
  # Perform memory cleanup
  #gc.collect()
  # Clear GPU memory
  torch.cuda.empty_cache()

for m in range(2,16):
    print("folder:"+str(m))
    train(m)
# Plot training and validation losses
# plt.plot(train_losses, label='Training Loss')
# plt.plot(val_losses, label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()
# Out:
# folder:2
# 5
# Epoch: 1, Loss: 0.9827186614274979
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.5003020521253347
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.46813889965415
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.4479948617517948
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.41627672500908375
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.4027475155889988
# Checkpoint saved at: /content/checkpoints/model_epoch_6.pth
# Epoch: 7, Loss: 0.4081223178654909
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:3
# 6
# Epoch: 1, Loss: 0.6622098702937365
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.37044692039489746
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.3386172503232956
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.3239249587059021
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.31244140677154064
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.302790991961956
# Checkpoint saved at: /content/checkpoints/model_epoch_6.pth
# Epoch: 7, Loss: 0.304325507953763
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:4
# 6
# Epoch: 1, Loss: 0.556103628128767
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.341709490865469
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.31740706227719784
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.3040665201842785
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.2937092399224639
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.29650487191975117
# Checkpoint saved at: /content/checkpoints/model_epoch_6.pth
# Epoch: 7, Loss: 0.28578001726418734
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:5
# 6
# Epoch: 1, Loss: 0.5136189106851816
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.3807229604572058
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.3620724193751812
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.34305731393396854
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.34132106974720955
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.33175773080438375
# Checkpoint saved at: /content/checkpoints/model_epoch_6.pth
# Epoch: 7, Loss: 0.33536193519830704
# Checkpoint saved at: /content/checkpoints/model_epoch_7.pth
# Epoch: 8, Loss: 0.3230350371450186
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:6
# 7
# Epoch: 1, Loss: 0.44406543485820293
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.35805718414485455
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.32738179713487625
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.3148971814662218
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.3110614353790879
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.30705342814326286
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:7
# 5
# Epoch: 1, Loss: 0.37417598254978657
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.31280999910086393
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.3066846327856183
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.293150388635695
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.2928496180102229
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:8
# 4
# Epoch: 1, Loss: 0.4565553106367588
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.37891984544694424
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.36066692881286144
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:9
# 2
# Epoch: 1, Loss: 0.47453000396490097
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.34568041283637285
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.32229815050959587
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.30893799662590027
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:10
# 3
# Epoch: 1, Loss: 0.36824589036405087
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.31571539491415024
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.29588852636516094
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.3032856471836567
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.292408125475049
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:11
# 4
# Epoch: 1, Loss: 0.4304394219070673
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.3910130374133587
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.3729137722402811
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.3612014278769493
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.36369348503649235
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:12
# 4
# Epoch: 1, Loss: 0.3439668258652091
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.3021321278065443
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.2885543145239353
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.28010283317416906
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.283528707921505
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.2819782979786396
# Checkpoint saved at: /content/checkpoints/model_epoch_6.pth
# Epoch: 7, Loss: 0.2784421415999532
# Checkpoint saved at: /content/checkpoints/model_epoch_7.pth
# Epoch: 8, Loss: 0.2759794434532523
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:13
# 7
# Epoch: 1, Loss: 0.3281686622649431
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.28289768379181623
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.26456524804234505
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.26014809124171734
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.2596432948485017
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.246832013130188
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:14
# 5
# Epoch: 1, Loss: 0.39472976326942444
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.3254310982301831
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.3113961014896631
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.30759927071630955
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.3083149939775467
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.3002933394163847
# Checkpoint saved at: /content/checkpoints/model_epoch_6.pth
# Epoch: 7, Loss: 0.30172702576965094
# Model is starting to overfit. Stopping training.
# Model saved.
# folder:15
# 6
# Epoch: 1, Loss: 0.41170933470129967
# Checkpoint saved at: /content/checkpoints/model_epoch_1.pth
# Epoch: 2, Loss: 0.3818260859698057
# Checkpoint saved at: /content/checkpoints/model_epoch_2.pth
# Epoch: 3, Loss: 0.3698486313223839
# Checkpoint saved at: /content/checkpoints/model_epoch_3.pth
# Epoch: 4, Loss: 0.3729670736938715
# Checkpoint saved at: /content/checkpoints/model_epoch_4.pth
# Epoch: 5, Loss: 0.37190015614032745
# Checkpoint saved at: /content/checkpoints/model_epoch_5.pth
# Epoch: 6, Loss: 0.3665958009660244
# Checkpoint saved at: /content/checkpoints/model_epoch_6.pth
# Epoch: 7, Loss: 0.3640791568905115
# Checkpoint saved at: /content/checkpoints/model_epoch_7.pth
# Epoch: 8, Loss: 0.3776151370257139
# Checkpoint saved at: /content/checkpoints/model_epoch_8.pth
# Epoch: 9, Loss: 0.37099662609398365
# Checkpoint saved at: /content/checkpoints/model_epoch_9.pth
# Model saved.

# %%
import numpy as np
import cv2
import torch
import torch.nn as nn
from PIL import Image
import gc
import os
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor, ToPILImage

# Define the U-Net model architecture

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Encoder
        self.encoder1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder2 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder3 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        self.encoder4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

        # Decoder
        self.decoder5 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder6 = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder7 = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        )
        self.decoder8 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=1)
        )

    def forward(self, x):
        # Encoder
        x1 = self.encoder1(x)
        x2 = self.encoder2(x1)
        x3 = self.encoder3(x2)
        x4 = self.encoder4(x3)

        # Decoder
        d5 = self.decoder5(x4)
        d4 = self.decoder6(torch.cat([d5, x3], dim=1))
        d3 = self.decoder7(torch.cat([d4, x2], dim=1))
        d2 = self.decoder8(torch.cat([d3, x1], dim=1))

        return d2

# Load the trained model
model = UNet()
model.load_state_dict(torch.load('/content/model2.pth'))

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Load and preprocess the input image
input_image = cv2.imread('/content/dataset/360p/1/45.jpg')
input_image = cv2.resize(input_image, (640, 360))
input_tensor = ToTensor()(input_image).unsqueeze(0).to(device)

# Set the model to evaluation mode
model.eval()

# Disable gradient calculation
with torch.no_grad():
    # Forward pass
    output_tensor = model(input_tensor)

# Convert the output tensor to a numpy array
output_image = output_tensor.squeeze(0).cpu().numpy()

# Convert the output tensor to a numpy array
output_image = output_tensor.squeeze(0).cpu().numpy()

# Transpose the output array to match the shape (height, width, channels)
output_image = np.transpose(output_image, (1, 2, 0))

# Scale the pixel values from [0, 1] to [0, 255]
output_image = (output_image * 255).astype(np.uint8)

# Convert the output array to a PIL image
output_image = Image.fromarray(output_image)

# Save the predicted image
output_image.save('/content/predicted/predicted_image.jpg')

# %%
import numpy as np
from PIL import Image

# Load the original and predicted images
original_image = Image.open('/content/dataset/720p/1/45.jpg')
predicted_image = Image.open('/content/predicted/predicted_image.jpg')

# Convert images to numpy arrays
original_array = np.array(original_image)
predicted_array = np.array(predicted_image)

# Calculate the pixel-wise difference
diff_array = np.abs(original_array - predicted_array)

# Calculate the number of mismatched pixels
num_mismatched_pixels = np.sum(diff_array > 0)

# Calculate the total number of pixels
total_pixels = original_array.size

# Calculate the accuracy as the percentage of matching pixels
accuracy = ((total_pixels - num_mismatched_pixels) / total_pixels) * 100

print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 3.13%
